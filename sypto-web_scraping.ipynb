# %% [markdown]
# # Bitcoin Backtesting Results: Athena V2 | Learn Crypto with Sypto
#
# - We will scrape the Backtesting results of Athena V2 using BeautifulSoup.
# - There are 3 tables in the web page showing performance of Athena V2 which is an Algo trading bot.
# - Following are the tables:
#     - table no 1 which has trading data from August 2017 to August 2019.
#     - table no 2 : November 2019 to oct 2021.
#     - table no 3 : October 2021 to August 2022
# - Merge data in above tables to create a dataframe for further analyis.
#
# - Data analysis using Microsoft Excel.

# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 28.4 MB/s eta 0:00:00
# ...

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd

# %% [markdown]
# # Scraping Website using BeautifulSoup

# %%
# creating HTML response object using urlopen.

url = 'https://learn.sypto.xyz/invest-in-bitcoin-athena-v2/'
page = urlopen(url)
page

# %%
# extracting HTML from the page

html_bytes = page.read()
html = html_bytes.decode("utf-8")

# %%
# lets see how first 500 chars look

print(html[0:500])
# Out:
# <!doctype html>
# <html lang="en-US">
# <head>
#
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=5, viewport-fit=cover">
# 	<link rel="profile" href="https://gmpg.org/xfn/11">
#
# 	<meta name='robots' content='index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1' />
#             <style>
#                 .wpaicg_toc h2{
#                     margin-bottom: 20px;
#                 }
#                 .wpaicg_toc{

# %%
# finding the index

title_index = html.find("<title>")


print(title_index)
# Out:
# 4336

# %%
# lets find start of the index and end index 

start_index = title_index + len('<title>')
end_index = html.find("</title>")
print(start_index)
print(end_index)
# Out:
# 4343
# 4407

# %%
# lets find the title
title = html[start_index:end_index]
title
# Out:
# 'Bitcoin Backtesting Results: Athena V2 | Learn Crypto with Sypto'

# %%
# lets make our html file more readable
# printvfirst 500 chars of HTML object

html = BeautifulSoup(html, 'lxml')
print(html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=5, viewport-fit=cover" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots"/>
#   <style>
#    .wpaicg_toc h2{
#                     margin-bottom: 20px;
#                 }
#                 .wpaicg_toc{
#                     list-style: none;
#                     margin: 0 0 30px 0!important;
#                     padding: 0!important;
#                 }
#                 .wpaicg_toc li{}
#                 .wpaicg_toc li ul{
#                     list-style: decimal;
#                 }
#                 .wpaicg_toc a{}
#                 .wpaicg_chat_widget{
#                     position: fixed;
#                 }
#                 .wpaicg_widget_left{
#                     bottom: 15px;
# ...

# %%
#<figure class="wp-block-table" data-block-type="core"><table><tbody><tr><td>Trade</td><td>Type</td><td>Date</td><td>Price</td><td>Type</td><td>Date</td><td>Price</td><td>Profit %</td><td>Run-up %</td><td>Drawdown %</td></tr><tr><td>1</td><td>Buy</td><td>29/08/2017</td><td>$4,485.39</td><td>Sell</td><td>04/09/2017</td><td>$4,124.54</td><td>-8.05</td><td>10.12</td><td>8.05</td></tr><tr><td>2</td><td>Buy</td><td>10/10/2017</td><td>$4,939.19</td><td>Sell</td><td>10/11/2017</td><td>$6,651.00</td><td>34.66</td><td>57.31</td><td>4.64</td></tr><tr><td>3</td><td>Buy</td><td>16/11/2017</td><td>$7,770.02</td><td>Sell</td><td>21/12/2017</td><td>$14,666.56</td><td>88.76</td><td>154.81</td><td>4.48</td></tr><tr><td>4</td><td>Buy</td><td>17/07/2018</td><td>$6,818.16</td><td>Sell</td><td>01/08/2018</td><td>$7,696.00</td><td>12.88</td><td>24.55</td><td>0</td></tr><tr><td>5</td><td>Buy</td><td>21/09/2018</td><td>$6,584.99</td><td>Sell</td><td>11/10/2018</td><td>$6,430.00</td><td>-2.35</td><td>3.86</td><td>3.95</td></tr><tr><td>6</td><td>Buy</td><td>15/10/2018</td><td>$6,715.60</td><td>Sell</td><td>25/10/2018</td><td>$6,505.55</td><td>-3.13</td><td>14.36</td><td>3.13</td></tr><tr><td>7</td><td>Buy</td><td>08/02/2019</td><td>$3,720.00</td><td>Sell</td><td>27/02/2019</td><td>$3,712.66</td><td>-0.2</td><td>12.85</td><td>4.08</td></tr><tr><td>8</td><td>Buy</td><td>02/04/2019</td><td>$4,198.00</td><td>Sell</td><td>25/04/2019</td><td>$5,146.80</td><td>22.6</td><td>33.4</td><td>0</td></tr><tr><td>9</td><td>Buy</td><td>03/05/2019</td><td>$5,600.00</td><td>Sell</td><td>04/06/2019</td><td>$8,005.00</td><td>42.95</td><td>62.04</td><td>0.22</td></tr><tr><td>10</td><td>Buy</td><td>16/06/2019</td><td>$9,074.26</td><td>Sell</td><td>01/07/2019</td><td>$10,525.10</td><td>15.99</td><td>53.95</td><td>1.37</td></tr></tbody></table></figure>

table = html.find_all("figure", class_ = "wp-block-table")
table
# Out:
# [<figure class="wp-block-table" data-block-type="core"><table><tbody><tr><td>Trade</td><td>Type</td><td>Date</td><td>Price</td><td>Type</td><td>Date</td><td>Price</td><td>Profit %</td><td>Run-up %</td><td>Drawdown %</td></tr><tr><td>1</td><td>Buy</td><td>29/08/2017</td><td>$4,485.39</td><td>Sell</td><td>04/09/2017</td><td>$4,124.54</td><td>-8.05</td><td>10.12</td><td>8.05</td></tr><tr><td>2</td><td>Buy</td><td>10/10/2017</td><td>$4,939.19</td><td>Sell</td><td>10/11/2017</td><td>$6,651.00</td><td>34.66</td><td>57.31</td><td>4.64</td></tr><tr><td>3</td><td>Buy</td><td>16/11/2017</td><td>$7,770.02</td><td>Sell</td><td>21/12/2017</td><td>$14,666.56</td><td>88.76</td><td>154.81</td><td>4.48</td></tr><tr><td>4</td><td>Buy</td><td>17/07/2018</td><td>$6,818.16</td><td>Sell</td><td>01/08/2018</td><td>$7,696.00</td><td>12.88</td><td>24.55</td><td>0</td></tr><tr><td>5</td><td>Buy</td><td>21/09/2018</td><td>$6,584.99</td><td>Sell</td><td>11/10/2018</td><td>$6,430.00</td><td>-2.35</td><td>3.86</t
# ...

# %% [markdown]
# # Creating and Merging data sets from the tables in web page
# - we will further scrape to get data from the tags in the htmls
# - since there are already irregularities in data we will do rest of the part in making pandas dataframe mannually.
# - and finally merge the dataframes into one final dataframe.

# %%
# # Trade	Type	Date	Price	Type	Date	Price	Profit %	Run-up %	Drawdown %

# for trade in table[0]:
#     Trade = trade.text
#     print(Trade)

# # table_trade1 = table[0].find_all("tr", class_ = "wp-block-table")
# # table_trade1

Trade1 = table[0].findAll("tr")
df1 = []
for i in Trade1[1:]:
    df1.append(i.text)
# t1 = t[1]
# t1 = t1.text
# t1
df1
# Out:
# ['1Buy29/08/2017$4,485.39Sell04/09/2017$4,124.54-8.0510.128.05',
#  '2Buy10/10/2017$4,939.19Sell10/11/2017$6,651.0034.6657.314.64',
#  '3Buy16/11/2017$7,770.02Sell21/12/2017$14,666.5688.76154.814.48',
#  '4Buy17/07/2018$6,818.16Sell01/08/2018$7,696.0012.8824.550',
#  '5Buy21/09/2018$6,584.99Sell11/10/2018$6,430.00-2.353.863.95',
#  '6Buy15/10/2018$6,715.60Sell25/10/2018$6,505.55-3.1314.363.13',
#  '7Buy08/02/2019$3,720.00Sell27/02/2019$3,712.66-0.212.854.08',
#  '8Buy02/04/2019$4,198.00Sell25/04/2019$5,146.8022.633.40',
#  '9Buy03/05/2019$5,600.00Sell04/06/2019$8,005.0042.9562.040.22',
#  '10Buy16/06/2019$9,074.26Sell01/07/2019$10,525.1015.9953.951.37']

# %%
# now we got the perfect format and we can make data frame from it mannualy with reference to the table on web page
df1 = [
        [1,'Buy','29/08/2017',4485.39,'Sell','04/09/2017',4124.54,-8.05,10.12,8.05],
        [2,'Buy','10/10/2017',4939.19,'Sell','10/11/2017',6651.00,34.66,57.31,4.64],
        [3,'Buy','16/11/2017',7770.02,'Sell','21/12/2017',14666.56,88.76,154.81,4.48],
        [4,'Buy','17/07/2018',6818.16,'Sell','01/08/2018',7696.00,12.88,24.55, 0],
        [5,'Buy','21/09/2018',6584.99,'Sell','11/10/2018',6430.00,-2.35,3.86,3.95],
        [6,'Buy','15/10/2018',6715.60,'Sell','25/10/2018',6505.55,-3.13,14.36,3.13],
        [7,'Buy','08/02/2019',3720.00,'Sell','27/02/2019',3712.66,-0.21,2.85,4.08],
        [8,'Buy','02/04/2019',4198.00,'Sell','25/04/2019',5146.80,22.6,33.4,0],
        [9,'Buy','03/05/2019',5600.00,'Sell','04/06/2019',8005.00,42.95,62.04,0.22],
        [10,'Buy','16/06/2019',9074.26,'Sell','01/07/2019',10525.10,15.99,53.95,1.37]
    ]
df1 = pd.DataFrame(df1)
df1
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Buy</td>
#       <td>29/08/2017</td>
#       <td>4485.39</td>
#       <td>Sell</td>
#       <td>04/09/2017</td>
#       <td>4124.54</td>
#       <td>-8.05</td>
#       <td>10.12</td>
#       <td>8.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Buy</td>
#       <td>10/10/2017</td>
#       <td>4939.19</td>
# ...

# %%
# for table 2 in the web page

Trade2 = table[1].findAll("tr")
df2 = []
for i in Trade2[1:]:
    df2.append(i.text)

df2
# Out:
# ['1Buy25/10/2019$8,779.51Sell08/11/2019$8,913.001.5218.123.52',
#  '2Buy06/01/2020$7,695.38Sell23/01/2020$8,466.0010.0119.540.3',
#  '3Buy28/01/2020$9,198.98Sell16/02/2020$9,667.115.0914.141.15',
#  '4Buy23/04/2020$7,459.69Sell10/05/2020$8,522.0014.2434.950.96',
#  '5Buy01/06/2020$9,950.00Sell11/06/2020$9,365.21-5.884.326.87',
#  '6Buy22/07/2020$9,470.00Sell22/08/2020$11,531.2321.7731.660.31',
#  '7Buy10/10/2020$11,179.79Sell26/11/2020$17,214.4553.9874.280.07',
#  '8Buy30/11/2020$19,484.21Sell09/12/2020$18,001.12-7.612.077.61',
#  '9Buy16/12/2020$19,888.00Sell21/01/2021$32,380.0062.81110.930',
#  '10Buy08/02/2021$41,950.00Sell23/02/2021$45,570.798.6339.10',
#  '11Buy13/03/2021$58,352.80Sell23/03/2021$53,271.34-8.715.988.71',
#  '12Buy10/04/2021$60,200.00Sell18/04/2021$57,900.01-3.827.733.82',
#  '13Buy26/07/2021$36,600.00Sell05/08/2021$37,642.032.8516.390.59',
#  '14Buy06/08/2021$42,599.00Sell07/09/2021$46,512.009.1924.230.36',
# ...

# %%
df2 =[
    [1,'Buy','25/10/2019',8779.51,'Sell','08/11/2019',8913.00,1.52,18.12,3.52],
    [2,'Buy','06/01/2020',7695.38,'Sell','23/01/2020',8466.00,10.01,19.54,0.3],
    [3,'Buy','28/01/2020',9198.98,'Sell','16/02/2020',9667.11,5.09,14.14,1.15],
    [4,'Buy','23/04/2020',7459.69,'Sell','10/05/2020',8522.00,14.24,34.95,0.96],
    [5,'Buy','01/06/2020',9950.00,'Sell','11/06/2020',9365.21,-5.88,4.32,6.87],
    [6,'Buy','22/07/2020',9470.00,'Sell','22/08/2020',11531.23,21.77,31.66,0.31],
    [7,'Buy','10/10/2020',11179.79,'Sell','26/11/2020',17214.45,53.98,74.28,0.07],
    [8,'Buy','30/11/2020',19484.21,'Sell','09/12/2020',18001.12,-7.61,2.07,7.61],
    [9,'Buy','16/12/2020',19888.00,'Sell','21/01/2021',32380.00,62.81,110.93,0],
    [10,'Buy','08/02/2021',41950.00,'Sell','23/02/2021',45570.79,8.63,39.1,0],
    [11,'Buy','13/03/2021',58352.80,'Sell','23/03/2021',53271.34,-8.71,5.98,8.71],
    [12,'Buy','10/04/2021',60200.00,'Sell','18/04/2021',57900.01,-3.82,7.73,3.82],
    [13,'Buy','26/07/2021',36600.00,'Sell','05/08/2021',37642.03,2.85,16.39,0.59],
    [14,'Buy','06/08/2021',42599.00,'Sell','07/09/2021',46512.00,9.19,24.23,0.36],
    [15,'Buy','08/09/2021',46868.57,'Sell','20/09/2021',43370.00,-7.46,4.21,7.46]
]

df2 = pd.DataFrame(df2)
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Buy</td>
#       <td>25/10/2019</td>
#       <td>8779.51</td>
#       <td>Sell</td>
#       <td>08/11/2019</td>
#       <td>8913.00</td>
#       <td>1.52</td>
#       <td>18.12</td>
#       <td>3.52</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Buy</td>
#       <td>06/01/2020</td>
#       <td>7695.38</td>
# ...

# %%
# for table 3 in the web page



Trade3 = table[2].findAll("tr")
df3 = []
for i in Trade3[1:]:
    df3.append(i.text)

df3
# Out:
# ['26Buy03/10/2021$48,843.20Sell27/10/2021$59,510.6321.8437.174',
#  '27Buy08/11/2021$67,000.00Sell16/11/2021$62,278.00-7.052.997.05',
#  '28Buy07/02/2022$44,500.00Sell17/02/2022$41,550.56-6.632.976.63',
#  '29Buy27/03/2022$45,400.00Sell06/04/2022$44,200.00-2.646.152.64',
#  '30Buy08/07/2022$21,888.00Sell13/07/2022$19,304.40-11.82.9212.1',
#  '31Buy18/07/2022$22,527.37Sell26/07/2022$20,762.45-7.837.777.83',
#  '32Buy29/07/2022$24,276.74Sell19/08/2022$23,180.40-4.523.857.73']

# %%
df3 = [
    [26,'Buy','03/10/2021',48843.20,'Sell','27/10/2021',59510.63,21.84,37.17, 4],
    [27,'Buy','08/11/2021',67000.00,'Sell','16/11/2021',62278.00,-7.05,2.99,7.05],
    [28,'Buy','07/02/2022',44500.00,'Sell','17/02/2022',41550.56,-6.63,2.97,6.63],
    [29,'Buy','27/03/2022',45400.00,'Sell','06/04/2022',44200.00,-2.64,6.15,2.64],
    [30,'Buy','08/07/2022',21888.00,'Sell','13/07/2022',19304.40,-11.8,2.92,12.1],
    [31,'Buy','18/07/2022',22527.37,'Sell','26/07/2022',20762.45,-7.83,7.77,7.83],
    [32,'Buy','29/07/2022',24276.74,'Sell','19/08/2022',23180.40,-4.52,3.85,7.73]
]
df3=pd.DataFrame(df3)
df3
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>26</td>
#       <td>Buy</td>
#       <td>03/10/2021</td>
#       <td>48843.20</td>
#       <td>Sell</td>
#       <td>27/10/2021</td>
#       <td>59510.63</td>
#       <td>21.84</td>
#       <td>37.17</td>
#       <td>4.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>27</td>
#       <td>Buy</td>
#       <td>08/11/2021</td>
# ...

# %% [markdown]
# ## Merging the data sets

# %%
final_df = pd.concat([df1, df2, df3], ignore_index=True)
final_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>Buy</td>
#       <td>29/08/2017</td>
#       <td>4485.39</td>
#       <td>Sell</td>
#       <td>04/09/2017</td>
#       <td>4124.54</td>
#       <td>-8.05</td>
#       <td>10.12</td>
#       <td>8.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>Buy</td>
#       <td>10/10/2017</td>
#       <td>4939.19</td>
# ...

# %% [markdown]
# ## cleaning the dataset
# - Naming the cols as in the website
# - Resetting the index or dropping it.

# %%
final_df.columns = ['Trade', 'Type', 
                    'Buy Date', 'Price', 
                    'Type','Sell Date', 
                    'Price', 'Profit %', 
                    'Run-up %', 'Drawdown %']

final_df = final_df.drop(columns=['Trade'])
final_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Type</th>
#       <th>Buy Date</th>
#       <th>Price</th>
#       <th>Type</th>
#       <th>Sell Date</th>
#       <th>Price</th>
#       <th>Profit %</th>
#       <th>Run-up %</th>
#       <th>Drawdown %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Buy</td>
#       <td>29/08/2017</td>
#       <td>4485.39</td>
#       <td>Sell</td>
#       <td>04/09/2017</td>
#       <td>4124.54</td>
#       <td>-8.05</td>
#       <td>10.12</td>
#       <td>8.05</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Buy</td>
#       <td>10/10/2017</td>
#       <td>4939.19</td>
# ...

# %% [markdown]
# # saving it to Excel file so that we can do further analysis.

# %%
final_df.to_excel('Sypto_athena_V2_trading_data.xlsx')
